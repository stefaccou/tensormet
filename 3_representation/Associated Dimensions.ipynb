# %%
from mpmath.tests.test_elliptic import test_jcn

from tucker_tensor import TuckerDecomposition
tucker = TuckerDecomposition.load_from_disk(
    dataset="fineweb-en",
    method="siiShifted",
    divergence="fr",
    dims=1000,
    rank=150,
    iterations=500
)
# Out:
# 2026-01-07 16:56:25.642613: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
top_k = 5
target_verb = "kick"
target_id = tucker.vocab["v2i"][target_verb]
activation_pattern = tucker.factors[0][target_id].detach().numpy()
top_dims = np.argpartition(activation_pattern, -top_k)[-top_k:]
top_dims = top_dims[np.argsort(activation_pattern[top_dims])[::-1]]
